# %% [markdown]
# <a href="https://colab.research.google.com/github/simonramsey0/cs315/blob/main/birthdays.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from math import perm

# %%
num = 1000
for N in range(2, num):
  print(N, ((num**N - perm(num, N)))/num**N)
# Out:
# 2 0.001
# 3 0.002998
# 4 0.005989006
# 5 0.009965049976
# 6 0.01491522472612
# 7 0.02082573337776328
# 8 0.027679953244118937
# 9 0.03545851361816599
# 10 0.04413938699560249
# 11 0.053697993125646465
# 12 0.06410731520126435
# 13 0.07533802741884918
# 14 0.08735863306240414
# 15 0.10013561219953049
# 16 0.11363357801653753
# 17 0.12781544076827292
# 18 0.1426425782752123
# 19 0.15807501186625847
# 20 0.17407158664079955
# 21 0.19059015490798356
# 22 0.2075877616549159
# 23 0.22502083089850777
# 24 0.24284535178784208
# 25 0.26101706334493385
# 26 0.2794916367613105
# 27 0.2982248542055165
# 28 0.3171727831419675
# 29 0.3362919452139924
# 30 0.35553947880278663
# 31 0.37487329443870304
# 32 0.39425222231110324
# 33 0.4136361511971479
# 34 0.4329861582076421
# 35 0.4522646288285822
# 36 0.47143536681958187
# 37 0.4904636936140769
# 38 0.5093165369503561
# 39 0.5279625085462425
# 40 0.5463719707129391
# 41 0.5645170918844215
# 42 0.5823718911171603
# 43 0.5999122716902395
# ...
